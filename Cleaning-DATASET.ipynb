# %%
# Importing library

import pandas as pd

# %%
# Importing Dataset

Bank=pd.read_csv("Bank_churn.csv")

# %%
# Dataset overview

Bank.info()

# %%
# Check for empty cell

Bank.isna().sum()

# %%
# Check for any negitive value in "Age" column

Bank[Bank["Age"]< 0]

# %%
# Check for any negitive value in each "numeric" column

Bank[Bank.select_dtypes(include="number")<0].any()

# %%
# Check for duplicate Rows

Bank[Bank.duplicated()]

# %%
# Check duplicate values Column vise

Bank.apply(lambda col: col.duplicated().any())
